# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
iris=load_iris()

# %%
data=pd.DataFrame(data=iris.data,columns=iris.feature_names)
data['target']=iris.target
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
from sklearn.cluster import KMeans
model=KMeans(n_clusters=3)
model.fit(data,data['target'])
data['cluster']=model.labels_
print("The Centers : ",model.cluster_centers_)
# Out:
# The Centers :  [[5.91568627e+00 2.76470588e+00 4.26470588e+00 1.33333333e+00
#   1.01960784e+00 4.44089210e-16]
#  [5.00600000e+00 3.42800000e+00 1.46200000e+00 2.46000000e-01
#   0.00000000e+00 1.00000000e+00]
#  [6.62244898e+00 2.98367347e+00 5.57346939e+00 2.03265306e+00
#   2.00000000e+00 2.00000000e+00]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['sepal length (cm)'], y=data['petal length (cm)'], hue=data['cluster'])
plt.title('K-Means Clustering on Iris Dataset')
# plt.xlabel('Sepal Length')
# plt.ylabel('petal Length')
# plt.legend(title='Cluster')
plt.show()
